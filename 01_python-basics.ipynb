# %%
print("안녕하세요 선수혁")
1 + 1
# Out:
# 안녕하세요 선수혁
# 2

# %%
name = "선수혁"
age = 25

# %%
print(name)
# Out:
# 선수혁

# %%
print(age)
# Out:
# 25

# %%
print("제 이름은", name, "이고 나이는", age, "살 입니다")
# Out:
# 제 이름은 선수혁 이고 나이는 25 살 입니다

# %%
species = ["Bacteroides", "Faecalibacterium", "Phocaeicola", "Prevotella"]
abundance = [120, 85, 45, 200]

# %%
print(species)
# Out:
# ['Bacteroides', 'Faecalibacterium', 'Phocaeicola', 'Prevotella']

# %%
print(species[0])
print(species[1])
print(len(species))
# Out:
# Bacteroides
# Faecalibacterium
# 4

# %%
for s in species:
    print(s)
# Out:
# Bacteroides
# Faecalibacterium
# Phocaeicola
# Prevotella

# %%
for i in range(len(species)):
    print(species[i], "의 양은", abundance[i])
# Out:
# Bacteroides 의 양은 120
# Faecalibacterium 의 양은 85
# Phocaeicola 의 양은 45
# Prevotella 의 양은 200

# %%
foods = ["요구르트", "김치", "된장", "치즈", "청국장"]
bacteria_count = [80, 120, 95, 60, 150]

# %%
print(foods[4])
# Out:
# 청국장

# %%
print(len(foods))
# Out:
# 5

# %%
print(len(bacteria_count))
# Out:
# 5

# %%
for s in foods:
    print(s)
# Out:
# 요구르트
# 김치
# 된장
# 치즈
# 청국장

# %%
for i in range(len(foods)):
    print(foods[i], "에는 유익균이", bacteria_count[i],"마리")
# Out:
# 요구르트 에는 유익균이 80 마리
# 김치 에는 유익균이 120 마리
# 된장 에는 유익균이 95 마리
# 치즈 에는 유익균이 60 마리
# 청국장 에는 유익균이 150 마리

# %%
print(sum(bacteria_count))
# Out:
# 505

# %%
total = 0
for c in bacteria_count:
    total = total+c
    print(total)
# Out:
# 80
# 200
# 295
# 355
# 505

# %%
import pandas as pd
print("pandas 버전:" , pd.__version__)
# Out:
# pandas 버전: 2.3.3

# %%
df = pd.DataFrame({
    "food":["유구르트", "김치", "된장", "치즈", "청국장"],
    "bacteria":[80, 120, 95, 60, 150],
    "type":["유제품", "채소", "장류", "유제품", "장류"]
})
df
# Out:
#    food  bacteria type
# 0  유구르트        80  유제품
# 1    김치       120   채소
# 2    된장        95   장류
# 3    치즈        60  유제품
# 4   청국장       150   장류

# %%
df.head(2)
# Out:
#    food  bacteria type
# 0  유구르트        80  유제품
# 1    김치       120   채소

# %%
df.head(4)
# Out:
#    food  bacteria type
# 0  유구르트        80  유제품
# 1    김치       120   채소
# 2    된장        95   장류
# 3    치즈        60  유제품

# %%
df.shape
# Out:
# (5, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   food      5 non-null      object
#  1   bacteria  5 non-null      int64
#  2   type      5 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 252.0+ bytes

# %%
df.describe()
# Out:
#          bacteria
# count    5.000000
# mean   101.000000
# std     35.071356
# min     60.000000
# 25%     80.000000
# 50%     95.000000
# 75%    120.000000
# max    150.000000

# %%
df["food"]
# Out:
# 0    유구르트
# 1      김치
# 2      된장
# 3      치즈
# 4     청국장
# Name: food, dtype: object

# %%
df["bacteria"].sum()
df["bacteria"].mean()
df["bacteria"].max()
df["bacteria"].min()
# Out:
# 60

# %%
df["bacteria"].sum()
# Out:
# np.int64(505)

# %%
df["bacteria"].max()
# Out:
# 150

# %%
df["bacteria"].min()
# Out:
# 60

# %%
df["bacteria"].mean()
# Out:
# np.float64(101.0)

# %%
df[df["bacteria"]>100]
# Out:
#   food  bacteria type
# 1   김치       120   채소
# 4  청국장       150   장류

# %%
df[df["type"]=="장류"]
# Out:
#   food  bacteria type
# 2   된장        95   장류
# 4  청국장       150   장류

# %%
df.groupby("type")["bacteria"].mean()
# Out:
# type
# 유제품     70.0
# 장류     122.5
# 채소     120.0
# Name: bacteria, dtype: float64

# %%
df.groupby("type")["bacteria"].sum()
# Out:
# type
# 유제품    140
# 장류     245
# 채소     120
# Name: bacteria, dtype: int64

# %%
df["bacteria"].sum()
# Out:
# np.int64(505)

# %%
df.groupby("type")["bacteria"].mean()
# Out:
# type
# 유제품     70.0
# 장류     122.5
# 채소     120.0
# Name: bacteria, dtype: float64

# %%
df.to_csv("food_data.cvs", index=False)
print("저장완료!")
# Out:
# 저장완료!

# %%
df.to_csv("food_data.csv", index=False)
print("저장 완료!")
# Out:
# 저장 완료!

# %%
df2 = pd.read_csv("food_data.csv")
df2
# Out:
#    food  bacteria type
# 0  유구르트        80  유제품
# 1    김치       120   채소
# 2    된장        95   장류
# 3    치즈        60  유제품
# 4   청국장       150   장류

# %%
df2.head()
# Out:
#    food  bacteria type
# 0  유구르트        80  유제품
# 1    김치       120   채소
# 2    된장        95   장류
# 3    치즈        60  유제품
# 4   청국장       150   장류

# %%
df2.head()
df2["bacteria"].mean()
df2[df2["bacteria"]>100]
# Out:
#   food  bacteria type
# 1   김치       120   채소
# 4  청국장       150   장류

# %%
df2["bacteria"].mean()
# Out:
# np.float64(101.0)

# %%
df.head()
# Out:
#    food  bacteria type
# 0  유구르트        80  유제품
# 1    김치       120   채소
# 2    된장        95   장류
# 3    치즈        60  유제품
# 4   청국장       150   장류

# %%
df[df["bacteria"]>100]
# Out:
#   food  bacteria type
# 1   김치       120   채소
# 4  청국장       150   장류

# %%
df.groupby("type")["bacteria"].mean()
# Out:
# type
# 유제품     70.0
# 장류     122.5
# 채소     120.0
# Name: bacteria, dtype: float64

# %%
import seaborn as sns
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.groupby("species")["sepal_length"].mean()
# Out:
# species
# setosa        5.006
# versicolor    5.936
# virginica     6.588
# Name: sepal_length, dtype: float64

# %%
iris.groupby("species")["sepal_length"].max()
# Out:
# species
# setosa        5.8
# versicolor    7.0
# virginica     7.9
# Name: sepal_length, dtype: float64

# %%
iris.groupby("species")["sepal_length"].min()
# Out:
# species
# setosa        4.3
# versicolor    4.9
# virginica     4.9
# Name: sepal_length, dtype: float64

# %%
iris[iris["sepal_length"]>7]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 102           7.1          3.0           5.9          2.1  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 125           7.2          3.2           6.0          1.8  virginica
# 129           7.2          3.0           5.8          1.6  virginica
# 130           7.4          2.8           6.1          1.9  virginica
# 131           7.9          3.8           6.4          2.0  virginica
# 135           7.7          3.0           6.1          2.3  virginica

# %%
iris[iris["species"]=="setosa"]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
iris[(iris["species"]=="setosa")&(iris["sepal_length"]>5)]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 14           5.8          4.0           1.2          0.2  setosa
# 15           5.7          4.4           1.5          0.4  setosa
# 16           5.4          3.9           1.3          0.4  setosa
# 17           5.1          3.5           1.4          0.3  setosa
# 18           5.7          3.8           1.7          0.3  setosa
# 19           5.1          3.8           1.5          0.3  setosa
# 20           5.4          3.4           1.7          0.2  setosa
# 21           5.1          3.7           1.5          0.4  setosa
# 23           5.1          3.3           1.7          0.5  setosa
# 27           5.2          3.5           1.5          0.2  setosa
# ...

# %%
import matplotlib.pyplot as plt

# %%
sns.scatterplot(data=iris, x="petal_length", y="petal_width", hue="species")
plt.show()

# %%
sns.scatterplot(data=iris, x="petal_width", y="petal_length", hue="species")
plt.show()

# %%
sns.scatterplot(data=iris, x="petal_length", y="petal_width", hue="species", palette="Set2")
plt.show()

# %%
sns.scatterplot(data=iris, x="petal_length", y="petal_width", hue="species", palette="colorblind")
plt.show()

# %%
sns.scatterplot(data=iris, x="petal_length", y="petal_width", hue="species",
                palette={"setosa":"red", "versicolor":"green", "virginica":"blue"})
plt.show()

# %%
X=iris[["sepal_length", "sepal_width", "petal_length", "petal_width"]]
y=iris["species"]
print(X.shape) #(150,4)
print(y.shape) #(150,)
# Out:
# (150, 4)
# (150,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(
    X, y, test_size=0.3, random_state=42)
print("학습용:", X_train.shape)
print("시험용:", X_test.shape)
# Out:
# 학습용: (105, 4)
# 시험용: (45, 4)

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)
y_pred=model.predict(X_test)
print(y_pred)
# Out:
# ['versicolor' 'setosa' 'virginica' 'versicolor' 'versicolor' 'setosa'
#  'versicolor' 'virginica' 'versicolor' 'versicolor' 'virginica' 'setosa'
#  'setosa' 'setosa' 'setosa' 'versicolor' 'virginica' 'versicolor'
#  'versicolor' 'virginica' 'setosa' 'virginica' 'setosa' 'virginica'
#  'virginica' 'virginica' 'virginica' 'virginica' 'setosa' 'setosa'
#  'setosa' 'setosa' 'versicolor' 'setosa' 'setosa' 'virginica' 'versicolor'
#  'setosa' 'setosa' 'setosa' 'virginica' 'versicolor' 'versicolor' 'setosa'
#  'setosa']

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test, y_pred)
print("정확도:", accuracy)
print(f"45개 중 {int(accuracy*45)}개 맞힘")
# Out:
# 정확도: 1.0
# 45개 중 45개 맞힘

# %%
importance=pd.DataFrame({
    "feature":X.columns,
    "importance":model.feature_importances_})
print(importance.sort_values("importance",ascending=False))
# Out:
#         feature  importance
# 2  petal_length    0.893264
# 3   petal_width    0.087626
# 1   sepal_width    0.019110
# 0  sepal_length    0.000000

# %%
"
